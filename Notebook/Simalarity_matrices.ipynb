# %%
import pandas as pd
import numpy as np

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

tags = ['NNP', 'VBZ', 'NN', 'VBN', 'VB', 'PDT', 'VBG', 'WP', 'VBP', 'WDT', 'WRB', 'MD', 'JJ', 'VBD', 'NNPS', 'NNS', 'JJR', 'PRP', 'JJS', 'PRP$', 'CD', 'EX', 'RP', 'FW', 'POS']
dfs_sim={}
for tag in tags:
    dfs_sim[tag] = pd.read_json(f"Data/Similarity_matrix_{tag}.json")

# %%
##Heatmap similarity matrix for tag NNP
dfs_sim["NNP"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag VBZ
dfs_sim["VBZ"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag NN
dfs_sim["NN"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag VBN
dfs_sim["VBN"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag VB
dfs_sim["VB"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag PDT
dfs_sim["PDT"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_e30ec_row0_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e30ec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >all</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e30ec_level0_row0" class="row_heading level0 row0" >all</th>
#       <td id="T_e30ec_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
##Heatmap similarity matrix for tag VBG
dfs_sim["VBG"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag WP
dfs_sim["WP"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_eecb6_row0_col0, #T_eecb6_row1_col1, #T_eecb6_row2_col2, #T_eecb6_row3_col3, #T_eecb6_row4_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_eecb6_row0_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_eecb6_row0_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_eecb6_row0_col3 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_eecb6_row0_col4 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_eecb6_row1_col0 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_eecb6_row1_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_eecb6_row1_col3 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_eecb6_row1_col4 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_eecb6_row2_col0, #T_eecb6_row2_col1, #T_eecb6_row2_col3, #T_eecb6_row2_col4, #T_eecb6_row4_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_eecb6_row3_col0 {
# ...

# %%
##Heatmap similarity matrix for tag VBP
dfs_sim["VBP"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag WDT
dfs_sim["WDT"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c9125_row0_col0, #T_c9125_row1_col1, #T_c9125_row2_col2, #T_c9125_row3_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c9125_row0_col1 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_c9125_row0_col2 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_c9125_row0_col3 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_c9125_row1_col0 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_c9125_row1_col2, #T_c9125_row1_col3, #T_c9125_row3_col0, #T_c9125_row3_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c9125_row2_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_c9125_row2_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_c9125_row2_col3 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_c9125_row3_col2 {
#   background-color: #fc9879;
#   color: #000000;
# }
# </style>
# <table id="T_c9125_">
#   <thead>
#     <tr>
# ...

# %%
##Heatmap similarity matrix for tag WRB
dfs_sim["WRB"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_e3832_row0_col0, #T_e3832_row1_col1, #T_e3832_row2_col2, #T_e3832_row3_col3, #T_e3832_row4_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e3832_row0_col1, #T_e3832_row4_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_e3832_row0_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_e3832_row0_col3 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_e3832_row0_col4 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_e3832_row1_col0 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_e3832_row1_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_e3832_row1_col3 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_e3832_row1_col4 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_e3832_row2_col0 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_e3832_row2_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# ...

# %%
##Heatmap similarity matrix for tag MD
dfs_sim["MD"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c6266_row0_col0, #T_c6266_row1_col1, #T_c6266_row2_col2, #T_c6266_row3_col3, #T_c6266_row4_col4, #T_c6266_row5_col5, #T_c6266_row6_col6, #T_c6266_row7_col7 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c6266_row0_col1, #T_c6266_row2_col4, #T_c6266_row4_col0 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_c6266_row0_col2, #T_c6266_row5_col2, #T_c6266_row7_col0 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_c6266_row0_col3 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_c6266_row0_col4 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_c6266_row0_col5, #T_c6266_row2_col1, #T_c6266_row2_col3 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_c6266_row0_col6, #T_c6266_row6_col0, #T_c6266_row6_col1, #T_c6266_row6_col2, #T_c6266_row6_col3, #T_c6266_row6_col4, #T_c6266_row6_col5, #T_c6266_row6_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c6266_row0_col7 {
# ...

# %%
##Heatmap similarity matrix for tag JJ
dfs_sim["JJ"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag VBD
dfs_sim["VBD"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag NNPS
dfs_sim["NNPS"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_907ef_row0_col0, #T_907ef_row0_col11, #T_907ef_row0_col14, #T_907ef_row1_col1, #T_907ef_row2_col2, #T_907ef_row3_col3, #T_907ef_row3_col12, #T_907ef_row3_col13, #T_907ef_row4_col4, #T_907ef_row5_col5, #T_907ef_row6_col6, #T_907ef_row7_col7, #T_907ef_row8_col8, #T_907ef_row8_col10, #T_907ef_row9_col9 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_907ef_row0_col1, #T_907ef_row0_col6, #T_907ef_row5_col1, #T_907ef_row8_col3 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_907ef_row0_col2, #T_907ef_row9_col7 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_907ef_row0_col3, #T_907ef_row7_col0 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_907ef_row0_col4, #T_907ef_row6_col0 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_907ef_row0_col5, #T_907ef_row5_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_907ef_row0_col7 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# ...

# %%
##Heatmap similarity matrix for tag NNS
dfs_sim["NNS"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# ...

# %%
##Heatmap similarity matrix for tag JJR
dfs_sim["JJR"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_ee2a8_row0_col0, #T_ee2a8_row1_col1, #T_ee2a8_row2_col2, #T_ee2a8_row3_col3, #T_ee2a8_row4_col4, #T_ee2a8_row5_col5, #T_ee2a8_row5_col10, #T_ee2a8_row6_col6, #T_ee2a8_row7_col7, #T_ee2a8_row8_col8, #T_ee2a8_row9_col9 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ee2a8_row0_col1, #T_ee2a8_row1_col8 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_ee2a8_row0_col2, #T_ee2a8_row1_col2, #T_ee2a8_row9_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_ee2a8_row0_col3 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_ee2a8_row0_col4 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_ee2a8_row0_col5, #T_ee2a8_row8_col3, #T_ee2a8_row9_col10 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_ee2a8_row0_col6, #T_ee2a8_row7_col5 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_ee2a8_row0_col7, #T_ee2a8_row3_col8 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# ...

# %%
##Heatmap similarity matrix for tag PRP
dfs_sim["PRP"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_11624_row0_col0, #T_11624_row1_col1, #T_11624_row2_col2, #T_11624_row3_col3, #T_11624_row4_col4, #T_11624_row5_col5, #T_11624_row6_col6, #T_11624_row7_col7, #T_11624_row8_col8 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_11624_row0_col1, #T_11624_row8_col6 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_11624_row0_col2 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_11624_row0_col3, #T_11624_row0_col5 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_11624_row0_col4, #T_11624_row1_col8, #T_11624_row3_col5 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_11624_row0_col6 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_11624_row0_col7 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_11624_row0_col8 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_11624_row1_col0, #T_11624_row6_col8 {
#   background-color: #fc9272;
#   color: #000000;
# }
# ...

# %%
##Heatmap similarity matrix for tag JJS
dfs_sim["JJS"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_cbb4a_row0_col0, #T_cbb4a_row1_col1, #T_cbb4a_row1_col11, #T_cbb4a_row2_col2, #T_cbb4a_row2_col10, #T_cbb4a_row3_col3, #T_cbb4a_row4_col4, #T_cbb4a_row5_col5, #T_cbb4a_row6_col6, #T_cbb4a_row7_col7, #T_cbb4a_row8_col8, #T_cbb4a_row9_col9 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_cbb4a_row0_col1, #T_cbb4a_row4_col8 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_cbb4a_row0_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_cbb4a_row0_col3, #T_cbb4a_row2_col6 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_cbb4a_row0_col4, #T_cbb4a_row3_col5 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_cbb4a_row0_col5, #T_cbb4a_row0_col6, #T_cbb4a_row0_col8, #T_cbb4a_row6_col0, #T_cbb4a_row6_col1, #T_cbb4a_row6_col2, #T_cbb4a_row6_col3, #T_cbb4a_row6_col4, #T_cbb4a_row6_col7, #T_cbb4a_row6_col9, #T_cbb4a_row6_col10, #T_cbb4a_row6_col11 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# ...

# %%
##Heatmap similarity matrix for tag PRP$
dfs_sim["PRP$"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_a4c9a_row0_col0, #T_a4c9a_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a4c9a_row0_col1, #T_a4c9a_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_a4c9a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >its</th>
#       <th class="col_heading level0 col1" >their</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4c9a_level0_row0" class="row_heading level0 row0" >its</th>
#       <td id="T_a4c9a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a4c9a_row0_col1" class="data row0 col1" >0.506524</td>
#     </tr>
#     <tr>
#       <th id="T_a4c9a_level0_row1" class="row_heading level0 row1" >their</th>
#       <td id="T_a4c9a_row1_col0" class="data row1 col0" >0.506524</td>
#       <td id="T_a4c9a_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
##Heatmap similarity matrix for tag CD
dfs_sim["CD"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_44b64_row0_col0, #T_44b64_row1_col1, #T_44b64_row2_col2, #T_44b64_row3_col3, #T_44b64_row4_col4, #T_44b64_row5_col5, #T_44b64_row6_col6, #T_44b64_row7_col7, #T_44b64_row8_col8, #T_44b64_row9_col9 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_44b64_row0_col1, #T_44b64_row2_col0, #T_44b64_row5_col2, #T_44b64_row7_col0, #T_44b64_row8_col0 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_44b64_row0_col2, #T_44b64_row0_col6 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_44b64_row0_col3, #T_44b64_row7_col9 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_44b64_row0_col4 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_44b64_row0_col5 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_44b64_row0_col7, #T_44b64_row4_col2 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_44b64_row0_col8 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_44b64_row0_col9 {
# ...

# %%
##Heatmap similarity matrix for tag EX
dfs_sim["EX"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_e99fb_row0_col0, #T_e99fb_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e99fb_row0_col1, #T_e99fb_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e99fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >There</th>
#       <th class="col_heading level0 col1" >there</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e99fb_level0_row0" class="row_heading level0 row0" >There</th>
#       <td id="T_e99fb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e99fb_row0_col1" class="data row0 col1" >0.641671</td>
#     </tr>
#     <tr>
#       <th id="T_e99fb_level0_row1" class="row_heading level0 row1" >there</th>
#       <td id="T_e99fb_row1_col0" class="data row1 col0" >0.641671</td>
#       <td id="T_e99fb_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
##Heatmap similarity matrix for tag RP
dfs_sim["RP"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_79508_row0_col0, #T_79508_row1_col1, #T_79508_row2_col2, #T_79508_row3_col3, #T_79508_row4_col4, #T_79508_row5_col5, #T_79508_row6_col6, #T_79508_row7_col7, #T_79508_row8_col8, #T_79508_row9_col9 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_79508_row0_col1, #T_79508_row1_col0 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_79508_row0_col2 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_79508_row0_col3 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_79508_row0_col4 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_79508_row0_col5, #T_79508_row5_col1, #T_79508_row9_col3 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_79508_row0_col6, #T_79508_row9_col6 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_79508_row0_col7 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_79508_row0_col8, #T_79508_row6_col2 {
#   background-color: #ffebe2;
# ...

# %%
##Heatmap similarity matrix for tag FW
dfs_sim["FW"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c33f5_row0_col0, #T_c33f5_row1_col1, #T_c33f5_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c33f5_row0_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_c33f5_row0_col2 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_c33f5_row1_col0, #T_c33f5_row1_col2, #T_c33f5_row2_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c33f5_row2_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# </style>
# <table id="T_c33f5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >etc</th>
#       <th class="col_heading level0 col1" >multi</th>
#       <th class="col_heading level0 col2" >log</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c33f5_level0_row0" class="row_heading level0 row0" >etc</th>
#       <td id="T_c33f5_row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
##Heatmap similarity matrix for tag POS
dfs_sim["POS"].head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_5a56a_row0_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_5a56a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >log</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a56a_level0_row0" class="row_heading level0 row0" >log</th>
#       <td id="T_5a56a_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#   </tbody>
# </table>
